# %% [markdown]
# # 1. Introduction

# %% [markdown]
# 1.1 Business Problem
#
# The objective of this capstone project is to analyse and select best district for vegetarian restaurant in Istanbul, Turkey.
# We are trying to address a question if an investor would like to open a vegetarian restaurant, what would be the best district?

# %% [markdown]
# # 2. Data

# %% [markdown]
# In order to solve this problem we would need following data
# - list of districts in Istanbul
# - lat and long information for each district
# - annual household income data for each district

# %% [markdown]
# # 3. Methodology

# %% [markdown]
# # 4. Results

# %% [markdown]
# # 5. Discussion

# %% [markdown]
# # 6. Conclusion
