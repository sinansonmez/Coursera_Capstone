# %% [markdown]
# # 1. Introduction

# %% [markdown]
# 1.1 Business Problem
#
# To be completed

# %% [markdown]
# 1.2 Audience

# %% [markdown]
# # 2. Data

# %% [markdown]
# 2.1. Location

# %% [markdown]
# # 3. Methodology

# %% [markdown]
# # 4. Results

# %% [markdown]
# # 5.
